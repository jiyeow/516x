# %% [markdown]
# # Text Scrapping Assignment
# Precipitation is a major driver for non-point source pollutants runoff, and the impact of precipitation may vary annually, seasonally, or even monthly. For example, soil is more prone to erosion during planting seasons (March-May) when land cover is minimal. Consequently, a similar precipitation events (intensity and duration) may result in greater soil erosion during planting season as compared to the late-growing season. <br>
#
# Therefore, it is important to understand the precipitation pattern when evaluating the fate and transport of non-point source pollutants. The objectives of this task are: <br>
# 1) To gather historical precipitation data through an open API <br>
# 2) Calculate 30-year average annual precipitation depth <br>
# 3) Calculate annual precipitation depth for the monitoring years (2016-2018) <br>
# 4) Compare annual precipitation depth to the 30-year average, then determine if it is a dry, normal, or wet year <br>
# 5) Calculate 30-year average monthly precipitation depth <br>
# 6) Calculate monthly precipitation depth, then determine if it is a dry, normal, or wet month <br>
#
# In the future development, this data will be paired with nutrient concentration and loading data to identify any possible correlations.

# %%
import bs4
import requests
from datetime import datetime
#import datetime as dt
import pandas as pd
import numpy as np
import json
import urllib

# %%
url_page = 'https://api.worldweatheronline.com/premium/v1/past-weather.ashx?key=3bbd19dc238c4542a08213223192409&q=42.2422,-95.0129&format=json&date=2016-01-01&enddate=2018-12-31'
#mytoken = 
#params = 'datasetid='+str(datasetid)+'&'+'locationid='+str(locationid)+'&'+'startdate='+str(start)+'&'+'enddate='+str(end)+'&'+'units=metric'+'&'+'limit=1000'
response = requests.get(url_page)

# %%
print(response.text)
# Out:
# {"data":{"request":[{"type":"LatLon","query":"Lat 42.24 and Lon -95.01"}],"weather":[{"date":"2016-01-01","astronomy":[{"sunrise":"08:49 AM","sunset":"05:58 PM","moonrise":"12:36 AM","moonset":"12:53 PM","moon_phase":"Last Quarter","moon_illumination":"50"}],"maxtempC":"-2","maxtempF":"28","mintempC":"-9","mintempF":"16","avgtempC":"-6","avgtempF":"22","totalSnow_cm":"0.0","sunHour":"8.7","uvIndex":"1","hourly":[{"time":"0","tempC":"-8","tempF":"18","windspeedMiles":"14","windspeedKmph":"22","winddirDegree":"288","winddir16Point":"WNW","weatherCode":"122","weatherIconUrl":[{"value":"http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png"}],"weatherDesc":[{"value":"Overcast"}],"precipMM":"0.0","precipInches":"0.0","humidity":"93","visibility":"10","visibilityMiles":"6","pressure":"1030","pressureInches":"31","cloudcover":"98","HeatIndexC":"-8","HeatIndexF":"18","DewPointC":"-9","DewPointF":"16","WindChillC":"-16","WindChillF":"4","WindGustMiles":"21","WindGustKmph":"34","FeelsLikeC":"-16","FeelsLikeF":"4","uvIndex":"0"},{"time":"300","tempC":"-8","tempF":"18","windspeedMiles":"17","windspeedKmph":"27","winddirDegree":"286","winddir16Point":"WNW","weatherCode":"122","weatherIconUrl":[{"value":"http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png"}],"weatherDesc":[{"value":"Overcast"}],"precipMM":"0.0","precipInches":"0.0","humidity":"94","visibility":"10","visibilityMiles":"6","pressure":"1029","pressureInches":"31","cloudcover":"92","HeatIndexC":"-8","HeatIndexF":"18","DewPointC":"-9","DewPointF":"17","WindChillC":"-16","WindChillF":"3","WindGustMiles":"25","WindGustKmph":"40","FeelsLikeC":"-16","FeelsLikeF":"3","uvIndex":"0"},{"time":"600","tempC":"-9","tempF":"16","windspeedMiles":"18","windspeedKmph":"29","winddirDegree":"272","winddir16Point":"W","weatherCode":"113","weatherIconUrl":[{"value":"http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png"}],"weatherDesc":[{"value":"Clear"}],"precipMM":"0.0","precipInches":"0.0","humidity":"90","visibility":"10","visibilityMiles":"6","pressure":"1028","pressureInches":"31","cloudcover":"23","HeatIndexC":"-9","HeatIndexF":"16","DewPointC":"-10","DewPointF":"13","WindChillC":"-18","WindChillF":"0","WindGustMiles":"32","WindGustKmph":"51","FeelsLikeC":"-18","FeelsLikeF":"0","uvIndex":"0"},{"time":"900","tempC":"-6","tempF":"21","windspeedMiles":"18","windspeedKmph":"30","winddirDegree":"268","winddir16Point":"W","weatherCode":"113","weatherIconUrl":[{"value":"http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png"}],"weatherDesc":[{"value":"Sunny"}],"precipMM":"0.0","precipInches":"0.0","humidity":"81","visibility":"10","visibilityMiles":"6","pressure":"1026","pressureInches":"31","cloudcover":"8","HeatIndexC":"-6","HeatIndexF":"21","DewPointC":"-9","DewPointF":"16","WindChillC":"-15","WindChillF":"6","WindGustMiles":"35","WindGustKmph":"56","FeelsLikeC":"-15","FeelsLikeF":"6","uvIndex":"2"},{"time":"1200","tempC":"-2","tempF":"28","windspeedMiles":"16","windspeedKmph":"26","winddirDegree":"246","winddir16Point":"WSW","weatherCode":"113","weatherIconUrl":[{"value":"http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png"}],"weatherDesc":[{"value":"Sunny"}],"precipMM":"0.0","precipInches":"0.0","humidity":"79","visibility":"10","visibilityMiles":"6","pressure":"1024","pressureInches":"31","cloudcover":"16","HeatIndexC":"-2","HeatIndexF":"28","DewPointC":"-5","DewPointF":"22","WindChillC":"-9","WindChillF":"16","WindGustMiles":"25","WindGustKmph":"41","FeelsLikeC":"-9","FeelsLikeF":"16","uvIndex":"2"},{"time":"1500","tempC":"-3","tempF":"27","windspeedMiles":"21","windspeedKmph":"35","winddirDegree":"252","winddir16Point":"WSW","weatherCode":"113","weatherIconUrl":[{"value":"http://cdn.worldweatheronline.net/images/wsymbols01_png_64/wsymbol_0001_sunny.png"}],"weatherDesc":[{"value":"Sunny"}],"precipMM":"0.0","precipInches": ...

# %%
print(type(response))
# Out:
# <class 'requests.models.Response'>

# %% [markdown]
# ## json_page = urllib.request.urlopen(url_page)
# weather = json.loads(json_page.read().decode())
# weather

# %%
print(type(weather))
print(len(weather))
print(weather.keys())
# Out:
# <class 'dict'>
# 1
# dict_keys(['data'])
